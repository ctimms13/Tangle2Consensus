# %% [markdown]
# ### Dissertation Tests

# %%
import block_tangle as bt

# %%
universe = bt.Universe()
universe.start_universe(8)
# Out:
# First node
# Finished updating
# Finished updating
# Finished updating
# Finished updating
# Finished updating
# Finished updating
# Finished updating
# Finished updating

# %%
universe.true_node_graph.plot_graph()

# %%
universe.true_node_graph.printStats()
# Out:
# Nodes RAW [<block_tangle.node object at 0x0000027A3E3E5DF0>, <block_tangle.node object at 0x0000027A1DC2EB40>, <block_tangle.node object at 0x0000027A1DC2F3B0>, <block_tangle.node object at 0x0000027A1DC2F350>, <block_tangle.node object at 0x0000027A1DC2F320>, <block_tangle.node object at 0x0000027A3E409B80>, <block_tangle.node object at 0x0000027A3E4448F0>, <block_tangle.node object at 0x0000027A3E444920>]
# Edges [(1, 0), (2, 1), (2, 0), (3, 0), (3, 2), (4, 3), (4, 2), (5, 0), (5, 4), (6, 1), (6, 3), (7, 3), (7, 6)]
# Node IDS [0, 1, 2, 3, 4, 5, 6, 7]
# Weights [[0, 1345, 0.14285714285714285], [1, 885, 0.14285714285714285], [2, 1644, 0.14285714285714285], [3, 1409, 0.14285714285714285], [4, 1273, 0.14285714285714285], [5, 877, 0.14285714285714285], [6, 1809, 0.14285714285714285], [7, 1185, 0.14285714285714285]]

# %%
#print(universe.true_node_graph.nodes)
for n in universe.true_node_graph.nodes:
    print(n)
    n.issue_block()
# Out:
# <block_tangle.node object at 0x0000027A3E3E5DF0>
# 0 0 1.010079835830226
# Into URTS [<Genesis>]
# [<Genesis>]
# <block_tangle.node object at 0x0000027A1DC2EB40>
# 0 0 1.0107962609664043
# 1 1.010079835830226 1.0107962609664043
# Into URTS [<Genesis>, <block_tangle.Block object at 0x0000027A3D369610>]
# [<Genesis>, <block_tangle.Block object at 0x0000027A3D369610>]
# <block_tangle.node object at 0x0000027A1DC2F3B0>
# 0 0 1.0113956914932245
# 1 1.010079835830226 1.0113956914932245
# 2 1.0107962609664043 1.0113956914932245
# Into URTS [<Genesis>, <block_tangle.Block object at 0x0000027A3D369610>, <block_tangle.Block object at 0x0000027A3E40AB10>]
# [<block_tangle.Block object at 0x0000027A3E40AB10>
#  <block_tangle.Block object at 0x0000027A3D369610>]
# <block_tangle.node object at 0x0000027A1DC2F350>
# 0 0 1.0115380015599515
# 1 1.010079835830226 1.0115380015599515
# 2 1.0107962609664043 1.0115380015599515
# 3 1.0113956914932245 1.0115380015599515
# Into URTS [<Genesis>, <block_tangle.Block object at 0x0000027A3D369610>, <block_tangle.Block object at 0x0000027A3E40AB10>, <block_tangle.Block object at 0x0000027A3D165100>]
# [<block_tangle.Block object at 0x0000027A3D369610>
#  <block_tangle.Block object at 0x0000027A3E40AB10>
#  <block_tangle.Block object at 0x0000027A3E40AB10>]
# <block_tangle.node object at 0x0000027A1DC2F320>
# 0 0 1.0142604631029029
# 1 1.010079835830226 1.0142604631029029
# 2 1.0107962609664043 1.0142604631029029
# 3 1.0113956914932245 1.0142604631029029
# 4 1.0115380015599515 1.0142604631029029
# Into URTS [<Genesis>, <block_tangle.Block object at 0x0000027A3D369610>, <block_tangle.Block object at 0x0000027A3E40AB10>, <block_tangle.Block object at 0x0000027A3D165100>, <block_tangle.Block object at 0x0000027A40528410>]
# [<block_tangle.Block object at 0x0000027A3D165100>
#  <block_tangle.Block object at 0x0000027A3D165100>
#  <block_tangle.Block object at 0x0000027A40528410>
#  <block_tangle.Block object at 0x0000027A3D165100>]
# <block_tangle.node object at 0x0000027A3E409B80>
# 0 0 1.0853414631346188
# 1 1.010079835830226 1.0853414631346188
# 2 1.0107962609664043 1.0853414631346188
# 3 1.0113956914932245 1.0853414631346188
# 4 1.0115380015599515 1.0853414631346188
# 5 1.0142604631029029 1.0853414631346188
# Into URTS [<Genesis>, <block_tangle.Block object at 0x0000027A3D369610>, <block_tangle.Block object at 0x0000027A3E40AB10>, <block_tangle.Block object at 0x0000027A3D165100>, <block_tangle.Block object at 0x0000027A40528410>, <block_tangle.Block object at 0x0000027A4052B890>]
# [<block_tangle.Block object at 0x0000027A4052B890>
#  <block_tangle.Block object at 0x0000027A4052B890>
#  <block_tangle.Block object at 0x0000027A40528410>
#  <block_tangle.Block object at 0x0000027A40528410>]
# <block_tangle.node object at 0x0000027A3E4448F0>
# 0 0 1.0912268333297714
# 1 1.010079835830226 1.0912268333297714
# 2 1.0107962609664043 1.0912268333297714
# 3 1.0113956914932245 1.0912268333297714
# 4 1.0115380015599515 1.0912268333297714
# 5 1.0142604631029029 1.0912268333297714
# 6 1.0853414631346188 1.0912268333297714
# Into URTS [<Genesis>, <block_tangle.Block object at 0x0000027A3D369610>, <block_tangle.Block object at 0x0000027A3E40AB10>, <block_tangle.Block object at 0x0000027A3D165100>, <block_tangle.Block object at 0x0000027A40528410>, <block_tangle.Block object at 0x0000027A4052B890>, <block_tangle.Block object at 0x0000027A4052B290>]
# [<block_tangle.Block object at 0x0000027A3E40AB10>
#  <block_tangle.Block object at 0x0000027A3D165100>
#  <block_tangle.Block object at 0x0000027A4052B890>
#  <block_tangle.Block object at 0x0000027A4052B890>
#  <block_tangle.Block object at 0x0000027A40528410>]
# <block_tangle.node object at 0x0000027A3E444920>
# 0 0 1.0922633818271743
# 1 1.010079835830226 1.0922633818271743
# 2 1.0107962609664043 1.0922633818271743
# 3 1.0113956914932245 1.0922633818271743
# 4 1.0115380015599515 1.0922633818271743
# 5 1.0142604631029029 1.0922633818271743
# 6 1.0853414631346188 1.0922633818271743
# 7 1.0912268333297714 1.0922633818271743
# Into URTS [<Genesis>, <block_tangle.Block object at 0x0000027A3D369610>, <block_tangle.Block object at 0x0000027A3E40AB10>, <block_tangle.Block object at 0x0000027A3D165100>, <block_tangle.Block object at 0x0000027A40528410>, <block_tangle.Block object at 0x0000027A4052B890>, <block_tangle.Block object at 0x0000027A4052B290>, <block_tangle.Block object at 0x0000027A3E4DE630>]
# [<block_tangle.Block object at 0x0000027A40528410>
#  <block_tangle.Block object at 0x0000027A4052B290>
#  <block_tangle.Block object at 0x0000027A3D369610>
#  <block_tangle.Block object at 0x0000027A4052B290>
#  <block_tangle.Block object at 0x0000027A4052B890>
#  <block_tangle.Block object at 0x0000027A4052B890>
#  <block_tangle.Block object at 0x0000027A3D369610>]

# %%
l = universe.true_block_tangle.blocks
print(l)
# Out:
# [<Genesis>, <block_tangle.Block object at 0x0000027A3D369610>, <block_tangle.Block object at 0x0000027A3E40AB10>, <block_tangle.Block object at 0x0000027A3D165100>, <block_tangle.Block object at 0x0000027A40528410>, <block_tangle.Block object at 0x0000027A4052B890>, <block_tangle.Block object at 0x0000027A4052B290>, <block_tangle.Block object at 0x0000027A3E4DE630>, <block_tangle.Block object at 0x0000027A3E4DDD30>]

# %%
universe.true_block_tangle.plotBlock()
