# %% [markdown]
# ### Dissertation Tests

# %%
import block_tangle as bt

# %%
universe = bt.Universe()
universe.start_universe(8)
# Out:
# First node
# Finished updating
# Finished updating
# Finished updating
# Finished updating
# Finished updating
# Finished updating
# Finished updating
# Finished updating

# %%
universe.true_node_graph.plot_graph()

# %%
universe.true_node_graph.printStats()
# Out:
# Nodes RAW [<block_tangle.node object at 0x000002DCA4D53CE0>, <block_tangle.node object at 0x000002DC8529B500>, <block_tangle.node object at 0x000002DC8529AFF0>, <block_tangle.node object at 0x000002DCA4DD8B30>, <block_tangle.node object at 0x000002DCA5F05370>, <block_tangle.node object at 0x000002DCA5F05C40>, <block_tangle.node object at 0x000002DCA4D31070>, <block_tangle.node object at 0x000002DCA4D306E0>]
# Edges [(1, 0), (2, 1), (2, 0), (3, 0), (3, 2), (4, 1), (4, 3), (5, 3), (5, 4), (6, 0), (6, 3), (7, 4), (7, 3)]
# Node IDS [0, 1, 2, 3, 4, 5, 6, 7]
# Weights [[0, 608, 0.14285714285714285], [1, 893, 0.14285714285714285], [2, 1945, 0.14285714285714285], [3, 531, 0.14285714285714285], [4, 1104, 0.14285714285714285], [5, 1947, 0.14285714285714285], [6, 140, 0.14285714285714285], [7, 495, 0.14285714285714285]]

# %%
print(universe.true_node_graph.nodes)
for n in universe.true_node_graph.nodes:
    print(n)
    n.issue_block()
# Out:
# [<block_tangle.node object at 0x000002DCA4D53CE0>, <block_tangle.node object at 0x000002DC8529B500>, <block_tangle.node object at 0x000002DC8529AFF0>, <block_tangle.node object at 0x000002DCA4DD8B30>, <block_tangle.node object at 0x000002DCA5F05370>, <block_tangle.node object at 0x000002DCA5F05C40>, <block_tangle.node object at 0x000002DCA4D31070>, <block_tangle.node object at 0x000002DCA4D306E0>]
# <block_tangle.node object at 0x000002DCA4D53CE0>
# 0 1.0117163480894598
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 4
#       2 for n in universe.true_node_graph.nodes:
#       3     print(n)
# ----> 4     n.issue_block()
#
# File c:\Users\catim\Documents\GitHub\Tangle2Consensus\block_tangle.py:120, in node.issue_block(self)
#     118 outputs = random.randint(0, 2000000000)
#     119 nodeSig = self.signature
# --> 120 self.block_tangle.next_block(inputs, outputs, nodeSig)
#
# File c:\Users\catim\Documents\GitHub\Tangle2Consensus\block_tangle.py:195, in block_tangle.next_block(self, inputs, outputs, sig)
#     193     approved_tips = set(self.mcmc())
#     194 elif self.tip_selection == 'urts':
# --> 195     approved_tips = set(self.urts())
#     196 else:
#     197     raise Exception()
#
# TypeError: 'Genesis' object is not iterable

# %%
l = universe.true_block_tangle.blocks
print(l)
# Out:
# [<block_tangle.Genesis object at 0x0000015D7F5F4E00>, <block_tangle.Block object at 0x0000015D7F630EF0>, <block_tangle.Block object at 0x0000015D71FAAFC0>, <block_tangle.Block object at 0x0000015D7F8DEF60>, <block_tangle.Block object at 0x0000015D7F8DED20>, <block_tangle.Block object at 0x0000015D7F7F4D70>, <block_tangle.Block object at 0x0000015D7F7F4AD0>, <block_tangle.Block object at 0x0000015D7F7F4E60>, <block_tangle.Block object at 0x0000015D7F7F4F20>]

# %%
universe.true_block_tangle.plotBlock()
