# %% [markdown]
# ### Dissertation Tests

# %%
from block_tangle import node_graph

# %%
n = node_graph()
n.new_node()
n.new_node()
n.new_node()
n.new_node()
n.new_node()
n.new_node()
n.new_node()
n.new_node()
# Out:
# First node
# Finished updating
# Finished updating
# Finished updating
# Finished updating
# Finished updating
# Finished updating
# Finished updating
# Finished updating

# %%
n.plot_graph()
