# %% [markdown]
# ### Dissertation Tests

# %%
import block_tangle as bt

# %%
universe = bt.Universe()
universe.start_universe(8)
# Out:
# First node
# Finished updating
# Finished updating
# Finished updating
# Finished updating
# Finished updating
# Finished updating
# Finished updating
# Finished updating

# %%
universe.true_node_graph.plot_graph()

# %%
universe.true_node_graph.printStats()
# Out:
# Nodes RAW [<block_tangle.node object at 0x0000020FDC86EF30>, <block_tangle.node object at 0x0000020FFBFA1520>, <block_tangle.node object at 0x0000020FDC86EE10>, <block_tangle.node object at 0x0000020FDC86F3B0>, <block_tangle.node object at 0x0000020FDC86F230>, <block_tangle.node object at 0x0000020FDC86F260>, <block_tangle.node object at 0x0000020FDC86F380>, <block_tangle.node object at 0x0000020FFBFB94F0>]
# Edges [(1, 0), (2, 0), (2, 1), (3, 0), (3, 1), (4, 3), (4, 1), (5, 4), (5, 1), (6, 3), (6, 4), (7, 0), (7, 4)]
# Node IDS [0, 1, 2, 3, 4, 5, 6, 7]
# Weights [[0, 1590, 0.14285714285714285], [1, 1756, 0.14285714285714285], [2, 474, 0.14285714285714285], [3, 215, 0.14285714285714285], [4, 1340, 0.14285714285714285], [5, 1058, 0.14285714285714285], [6, 570, 0.14285714285714285], [7, 1632, 0.14285714285714285]]

# %%
print(universe.true_node_graph.nodes)
for n in universe.true_node_graph.nodes:
    print(n)
    n.issue_block()
# Out:
# [<block_tangle.node object at 0x0000020FDC86EF30>, <block_tangle.node object at 0x0000020FFBFA1520>, <block_tangle.node object at 0x0000020FDC86EE10>, <block_tangle.node object at 0x0000020FDC86F3B0>, <block_tangle.node object at 0x0000020FDC86F230>, <block_tangle.node object at 0x0000020FDC86F260>, <block_tangle.node object at 0x0000020FDC86F380>, <block_tangle.node object at 0x0000020FFBFB94F0>]
# <block_tangle.node object at 0x0000020FDC86EF30>
# <block_tangle.node object at 0x0000020FFBFA1520>
# <block_tangle.node object at 0x0000020FDC86EE10>
# <block_tangle.node object at 0x0000020FDC86F3B0>
# <block_tangle.node object at 0x0000020FDC86F230>
# <block_tangle.node object at 0x0000020FDC86F260>
# <block_tangle.node object at 0x0000020FDC86F380>
# <block_tangle.node object at 0x0000020FFBFB94F0>

# %%
l = universe.true_block_tangle.blocks
print(l)
# Out:
# [<block_tangle.Genesis object at 0x0000020FFBEA66C0>, <block_tangle.Block object at 0x0000020FFD0EB2F0>, <block_tangle.Block object at 0x0000020FFD0949B0>, <block_tangle.Block object at 0x0000020FFD07F560>, <block_tangle.Block object at 0x0000020FFF17ADE0>, <block_tangle.Block object at 0x0000020FFF17A210>, <block_tangle.Block object at 0x0000020FFF17A660>, <block_tangle.Block object at 0x0000020FFF178230>, <block_tangle.Block object at 0x0000020FFF17B680>]
